# %%
import pandas as pd
import seaborn as sns

# %%
songs_df=pd.read_csv('../data/raw/spotify_songs.csv')

# %%
songs_df.head(5)
# Out:
#    Unnamed: 0  \
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4
#
#   name                                                                                                                                                                               \
# 0  Se Eu Quiser Falar Com Deus                   ...
# 1  Saudade De Bahia                              ...
# 2  Canta Canta, Minha Gente                      ...
# 3  Mulher Eu Sei                                 ...
# 4  Rosa Morena                                   ...
#
#    artist                                            danceability   energy     \
# 0  Gilberto Gil                                              0.658     0.2590
# 1  Antônio Carlos Jobim                                      0.742     0.3990
# 2  Martinho Da Vila                                          0.851     0.7300
# 3  Chico César                                               0.705     0.0502
# ...

# %%
columns_info_df = pd.DataFrame({
    'Non-Null Count': songs_df.count().values,
    'Dtype': songs_df.dtypes.values
}).set_index(songs_df.columns)

# %%
columns_info_df
# Out:
#                                                     Non-Null Count    Dtype
# Unnamed: 0                                                    5235    int64
# name                                           ...            5235   object
# artist                                                        5235   object
# danceability                                                  5235  float64
# energy                                                        5235  float64
# key                                                           5235    int64
# loudness                                                      5235  float64
# mode                                                          5235    int64
# speechiness                                                   5235  float64
# acousticness                                                  5235  float64
# instrumentalness                                              5235  float64
# ...

# %%
songs_df.columns.to_list()
# Out:
# ['Unnamed: 0',
#  'name                                                                                                                                                                             ',
#  'artist                                          ',
#  'danceability ',
#  'energy   ',
#  'key ',
#  'loudness ',
#  'mode ',
#  'speechiness ',
#  'acousticness ',
#  'instrumentalness ',
#  'liveness ',
#  'valence ',
#  'tempo   ',
#  'type ',
#  'duration_ms ',
#  'time_signature ',
#  'id                     ',
#  'html']

# %%
songs_df.columns=songs_df.columns.str.strip()

# %%
songs_df.describe()
# Out:
#        Unnamed: 0  danceability     energy            key     loudness   \
# count  5235.00000    5235.000000  5235.000000  5235.000000  5235.000000
# mean   2617.00000       0.509503     0.653565     5.254441    -9.338098
# std    1511.35866       0.218041     0.288335     3.571559     6.294850
# min       0.00000       0.000000     0.000000     0.000000   -60.000000
# 25%    1308.50000       0.309000     0.479000     2.000000   -11.337000
# 50%    2617.00000       0.539000     0.738000     5.000000    -7.338000
# 75%    3925.50000       0.688000     0.893000     8.000000    -5.264000
# max    5234.00000       0.967000     1.000000    11.000000     1.342000
#
#              mode   speechiness   acousticness   instrumentalness   \
# count  5235.000000   5235.000000    5235.000000        5235.000000
# mean      0.646227      0.083178       0.290043           0.257337
# std       0.478185      0.071193       0.355985           0.370686
# ...

# %%
songs_df['loudness '].describe()
# Out:
# count    5235.000000
# mean       -9.338098
# std         6.294850
# min       -60.000000
# 25%       -11.337000
# 50%        -7.338000
# 75%        -5.264000
# max         1.342000
# Name: loudness , dtype: float64

# %% [markdown]
# #### Loudness must be below zero, but it seems to have some positive values

# %%
songs_df.loc[songs_df['loudness ']>0]
# Out:
#       Unnamed: 0  \
# 372          372
# 373          373
# 917          917
# 2898        2898
#
#      name                                                                                                                                                                               \
# 372   Alright                                       ...
# 373   Gone                                          ...
# 917   Little Bitty Pretty One                       ...
# 2898  We Are Your Friends - Justice Vs Simian       ...
#
#       artist                                            danceability   \
# 372   Big Surr                                                  0.377
# 373   Big Surr                                                  0.386
# 917   Thurston Harris                                           0.703
# 2898  Justice                                                   0.615
#
#       energy     key   loudness   mode   speechiness   acousticness   \
# ...

# %%
songs_df.isnull().sum()
# Out:
# Unnamed: 0                                                                                                                                                                           0
# name                                                                                                                                                                                 0
# artist                                                                                                                                                                               0
# danceability                                                                                                                                                                         0
# energy                                                                                                                                                                               0
# ...

# %%
songs_df.hist(figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'Unnamed: 0'}>,
#         <Axes: title={'center': 'danceability '}>,
#         <Axes: title={'center': 'energy   '}>,
#         <Axes: title={'center': 'key '}>],
#        [<Axes: title={'center': 'loudness '}>,
#         <Axes: title={'center': 'mode '}>,
#         <Axes: title={'center': 'speechiness '}>,
#         <Axes: title={'center': 'acousticness '}>],
#        [<Axes: title={'center': 'instrumentalness '}>,
#         <Axes: title={'center': 'liveness '}>,
#         <Axes: title={'center': 'valence '}>,
#         <Axes: title={'center': 'tempo   '}>],
#        [<Axes: title={'center': 'duration_ms '}>,
#         <Axes: title={'center': 'time_signature '}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
sns.heatmap(songs_df.drop(['name','artist','Unnamed: 0','type','id','html'],axis=1).corr(), cmap="coolwarm")
# Out:
# <Axes: >
